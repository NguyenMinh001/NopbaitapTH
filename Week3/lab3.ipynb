# %%
#Van de 1
import pandas as pd


column_names = [
    "Id", "Name", "Age", "Weight",
    "m0006", "m0612", "m1218",
    "f0006", "f0612", "f1218"
]

df = pd.read_csv(
    "patient_heart_rate.csv",
    names=column_names,
    on_bad_lines="skip",   
    engine="python"        
)


print(df.head())


print(df.info())
# Out:
#     Id            Name   Age      Weight m0006 m0612 m1218 f0006 f0612 f1218
# 0  1.0    Mickéy Mousé  56.0       70kgs    72    69    71     -     -     -
# 1  2.0     Donald Duck  34.0   154.89lbs     -     -     -    85    84    76
# 2  3.0      Mini Mouse  16.0         NaN     -     -     -    65    69    72
# 3  4.0  Scrooge McDuck   NaN       78kgs    78    79    72     -     -     -
# 4  5.0    Pink Panther  54.0  198.658lbs     -     -     -    69   NaN    75
# <class 'pandas.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      14 non-null     float64
#  1   Name    13 non-null     str
#  2   Age     11 non-null     float64
#  3   Weight  11 non-null     str
#  4   m0006   14 non-null     str
#  5   m0612   14 non-null     str
#  6   m1218   14 non-null     str
#  7   f0006   14 non-null     str
#  8   f0612   13 non-null     str
# ...

# %%
#Van de 2



import pandas as pd


column_names = [
    "Id", "Name", "Age", "Weight",
    "m0006", "m0612", "m1218",
    "f0006", "f0612", "f1218"
]

df = pd.read_csv(
    "patient_heart_rate.csv",
    names=column_names,
    on_bad_lines="skip",
    engine="python"
)


df[["Firstname", "Lastname"]] = df["Name"].str.split(expand=True)


df = df.drop("Name", axis=1)


print(df.head())
# Out:
#     Id   Age      Weight m0006 m0612 m1218 f0006 f0612 f1218 Firstname  \
# 0  1.0  56.0       70kgs    72    69    71     -     -     -    Mickéy
# 1  2.0  34.0   154.89lbs     -     -     -    85    84    76    Donald
# 2  3.0  16.0         NaN     -     -     -    65    69    72      Mini
# 3  4.0   NaN       78kgs    78    79    72     -     -     -   Scrooge
# 4  5.0  54.0  198.658lbs     -     -     -    69   NaN    75      Pink
#
#   Lastname
# 0    Mousé
# 1     Duck
# 2    Mouse
# 3   McDuck
# 4  Panther

# %%
#Van de 3


import pandas as pd

column_names = [
    "Id", "Name", "Age", "Weight",
    "m0006", "m0612", "m1218",
    "f0006", "f0612", "f1218"
]

df = pd.read_csv(
    "patient_heart_rate.csv",
    names=column_names,
    on_bad_lines="skip",
    engine="python"
)

weight = df["Weight"]

for i in range(len(weight)):
    x = str(weight[i]).lower()

    if "lbs" in x:
        
        x = x.replace("lbs", "").strip()

        x = float(x)

        y = x / 2.2

        weight[i] = str(round(y, 2)) + "kgs"

print(df.head())
# Out:
#     Id            Name   Age      Weight m0006 m0612 m1218 f0006 f0612 f1218
# 0  1.0    Mickéy Mousé  56.0       70kgs    72    69    71     -     -     -
# 1  2.0     Donald Duck  34.0   154.89lbs     -     -     -    85    84    76
# 2  3.0      Mini Mouse  16.0         NaN     -     -     -    65    69    72
# 3  4.0  Scrooge McDuck   NaN       78kgs    78    79    72     -     -     -
# 4  5.0    Pink Panther  54.0  198.658lbs     -     -     -    69   NaN    75

# %%
#Van de 4

import pandas as pd

column_names = [
    "Id", "Name", "Age", "Weight",
    "m0006", "m0612", "m1218",
    "f0006", "f0612", "f1218"
]

df = pd.read_csv(
    "patient_heart_rate.csv",
    names=column_names,
    on_bad_lines="skip",
    engine="python"
)

df.dropna(how="all", inplace=True)

print(df)
# Out:
#       Id            Name   Age      Weight m0006 m0612 m1218 f0006 f0612 f1218
# 0    1.0    Mickéy Mousé  56.0       70kgs    72    69    71     -     -     -
# 1    2.0     Donald Duck  34.0   154.89lbs     -     -     -    85    84    76
# 2    3.0      Mini Mouse  16.0         NaN     -     -     -    65    69    72
# 3    4.0  Scrooge McDuck   NaN       78kgs    78    79    72     -     -     -
# 4    5.0    Pink Panther  54.0  198.658lbs     -     -     -    69   NaN    75
# 5    6.0     Huey McDuck  52.0      189lbs     -     -     -    68    75    72
# 6    7.0    Dewey McDuck  19.0       56kgs     -     -     -    71    78    75
# 7    8.0      Scööpy Doo  32.0       78kgs    78    76    75     -     -     -
# 10   9.0     Huey McDuck  52.0      189lbs     -     -     -    68    75    72
# 11  10.0    Louie McDuck  12.0       45kgs     -     -     -    92    95    87
# 12  11.0       Henry Nam   NaN       60kgs    78    75    72     -     -     -
# ...

# %%
# Vấn đề 5: 

import pandas as pd

column_names = [
    "Id", "Name", "Age", "Weight",
    "m0006", "m0612", "m1218",
    "f0006", "f0612", "f1218"
]

df = pd.read_csv(
    "patient_heart_rate.csv",
    names=column_names,
    on_bad_lines="skip",
    engine="python"
)


df["Name"] = df["Name"].fillna("Unknown_Unknown")


df[["Firstname", "Lastname"]] = df["Name"].str.split("_", n=1, expand=True)


df = df.drop_duplicates(subset=["Firstname", "Lastname", "Age", "Weight"])

print(df.head())
# Out:
#     Id            Name   Age      Weight m0006 m0612 m1218 f0006 f0612 f1218  \
# 0  1.0    Mickéy Mousé  56.0       70kgs    72    69    71     -     -     -
# 1  2.0     Donald Duck  34.0   154.89lbs     -     -     -    85    84    76
# 2  3.0      Mini Mouse  16.0         NaN     -     -     -    65    69    72
# 3  4.0  Scrooge McDuck   NaN       78kgs    78    79    72     -     -     -
# 4  5.0    Pink Panther  54.0  198.658lbs     -     -     -    69   NaN    75
#
#         Firstname Lastname
# 0    Mickéy Mousé      NaN
# 1     Donald Duck      NaN
# 2      Mini Mouse      NaN
# 3  Scrooge McDuck      NaN
# 4    Pink Panther      NaN

# %%
#Van de 6

import pandas as pd

column_names = [
    "Id", "Name", "Age", "Weight",
    "m0006", "m0612", "m1218",
    "f0006", "f0612", "f1218"
]

df = pd.read_csv(
    "patient_heart_rate.csv",
    names=column_names,
    on_bad_lines="skip",
    engine="python"
)


df[["Firstname", "Lastname"]] = df["Name"].str.split(" ", n=1, expand=True)


df["Firstname"] = df["Firstname"].replace(
    r"[^\x00-\x7F]+", "warning", regex=True
)

df["Lastname"] = df["Lastname"].replace(
    r"[^\x00-\x7F]+", "warning", regex=True
)

print(df[["Name", "Firstname", "Lastname"]].head())
# Out:
#              Name     Firstname     Lastname
# 0    Mickéy Mousé  Mickwarningy  Mouswarning
# 1     Donald Duck        Donald         Duck
# 2      Mini Mouse          Mini        Mouse
# 3  Scrooge McDuck       Scrooge       McDuck
# 4    Pink Panther          Pink      Panther

# %%
#Van de 7


import pandas as pd
import numpy as np


column_names = [
    "Id", "Name", "Age", "Weight",
    "m0006", "m0612", "m1218",
    "f0006", "f0612", "f1218"
]


df = pd.read_csv(
    "patient_heart_rate.csv",
    names=column_names,
    on_bad_lines="skip",
    engine="python"
)


print("Thống kê dữ liệu thiếu (trước xử lý):")
print(df[["Age", "Weight"]].isna().sum())
print("-" * 40)


df = df.dropna(subset=["Age", "Weight"], how="all")


age_mean = df["Age"].mean()
df["Age"] = df["Age"].fillna(age_mean)


df["Weight"] = (
    df["Weight"]
    .astype(str)
    .str.extract(r"([\d\.]+)")
    .astype(float)
)


print("Thống kê dữ liệu thiếu (sau xử lý):")
print(df[["Age", "Weight"]].isna().sum())
print("-" * 40)

print("Dữ liệu sau xử lý:")
print(df.head())
# Out:
# Thống kê dữ liệu thiếu (trước xử lý):
# Age       5
# Weight    5
# dtype: int64
# ----------------------------------------
# Thống kê dữ liệu thiếu (sau xử lý):
# Age       0
# Weight    2
# dtype: int64
# ----------------------------------------
# Dữ liệu sau xử lý:
#     Id            Name        Age   Weight m0006 m0612 m1218 f0006 f0612 f1218
# 0  1.0    Mickéy Mousé  56.000000   70.000    72    69    71     -     -     -
# 1  2.0     Donald Duck  34.000000  154.890     -     -     -    85    84    76
# 2  3.0      Mini Mouse  16.000000      NaN     -     -     -    65    69    72
# 3  4.0  Scrooge McDuck  37.545455   78.000    78    79    72     -     -     -
# 4  5.0    Pink Panther  54.000000  198.658     -     -     -    69   NaN    75

# %%
import pandas as pd
import numpy as np


column_names = [
    "Id", "Name", "Age", "Weight",
    "m0006", "m0612", "m1218",
    "f0006", "f0612", "f1218"
]


df = pd.read_csv(
    "patient_heart_rate.csv",
    names=column_names,
    on_bad_lines="skip",
    engine="python"
)


# ===== 3. Loại bỏ các dòng không có giá trị PulseRate =====
df_melt = df_melt.dropna(subset=["PulseRate"])

# ===== 4. Tách Sex và Time từ tên cột =====
df_melt["Sex"] = df_melt["sex_time"].str[0]      # m / f
df_melt["Time"] = df_melt["sex_time"].str[1:]    # 0006, 0612, 1218

# ===== 5. Chuẩn hóa Time =====
df_melt["Time"] = df_melt["Time"].map({
    "0006": "00-06",
    "0612": "06-12",
    "1218": "12-18"
})

# ===== 6. Sắp xếp & chọn cột cuối cùng =====
result = df_melt[
    ["Id", "Age", "Weight", "First name", "Last name", "PulseRate", "Sex", "Time"]
].sort_values(["Id", "Time"])

# ===== 7. Hiển thị kết quả =====
print(result)
# Out:
# Index(['Id', 'Name', 'Age', 'Weight', 'm0006', 'm0612', 'm1218', 'f0006',
#        'f0612', 'f1218'],
#       dtype='str')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 7
#       4 print(df.columns)
#       6 # ===== 2. Chuyển dữ liệu từ wide → long =====
# ----> 7 df_melt = df.melt(
#       8     id_vars=["Id", "Age", "Weight", "First name", "Last name"],
#       9     var_name="sex_time",
#      10     value_name="PulseRate"
#      11 )
#      13 # ===== 3. Loại bỏ các dòng không có giá trị PulseRate =====
#      14 df_melt = df_melt.dropna(subset=["PulseRate"])
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:11697, in DataFrame.melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#   11567 def melt(
#   11568     self,
#   11569     id_vars=None,
#    (...)  11574     ignore_index: bool = True,
# ...
